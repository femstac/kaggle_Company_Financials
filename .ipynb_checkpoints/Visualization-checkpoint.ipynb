# %% [markdown]
# Pre-processing:
# 1. Check for column names and Fix Errors
# 2. Remove $ sign and '-' from all columns where they are present
# 3. Change datatype from objects to int after the above two.
# 4. Removing " , " (comma) from all numerical numbers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import squarify
import textwrap
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
import holoviews as hv

from holoviews import opts
hv.extension('bokeh')
import matplotlib as mpl
from panel.interact import interact
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3aadc5be-6ef2-4470-b833-f25615220248'>
#   <div id="f951c026-f2dd-44a9-a3cd-740803ee7d92" data-root-id="3aadc5be-6ef2-4470-b833-f25615220248" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"19c871f5-50a0-4ee8-85fc-29ea563833f6":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"3aadc5be-6ef2-4470-b833-f25615220248"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d85731c1-e12f-487c-90a3-e73445cdfb68","attributes":{"plot_id":"3aadc5be-6ef2-4470-b833-f25615220248","comm_id":"01f22d2204ae4ebf81348465156a0c55","client_comm_id":"a8853e0861f8449a9c984de653ece13a"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"19c871f5-50a0-4ee8-85fc-29ea563833f6","roots":{"3aadc5be-6ef2-4470-b833-f25615220248":"f951c026-f2dd-44a9-a3cd-740803ee7d92"},"root_ids":["3aadc5be-6ef2-4470-b833-f25615220248"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ### Check File Contents

# %%
df = pd.read_csv('Financials.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None    $1,618.50
# 1  Government  Germany   Carretera            None    $1,321.00
# 2   Midmarket   France   Carretera            None    $2,178.00
# 3   Midmarket  Germany   Carretera            None      $888.00
# 4   Midmarket   Mexico   Carretera            None    $2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit         Date  Month Number  Month Name   Year
# 0   $16,185.00    $16,185.00   01/01/2014             1     January   2014
# 1   $13,210.00    $13,210.00   01/01/2014             1     January   2014
# 2   $21,780.00    $10,890.00   01/06/2014             6        June   2014
# 3    $8,880.00     $4,440.00   01/06/2014             6        June   2014
# 4   $24,700.00    $12,350.00   01/06/2014             6        June   2014

# %% [markdown]
# ### Trim All White spaces in object columns in the dataset

# %%
df_obj = df.select_dtypes(['object', 'string'])

df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', ' Units Sold ',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %% [markdown]
# ### create variables

# %%
[
 Segment, Country, Product,
 Discount_Band, Units_Sold,
 Manufacturing_Price, Sale_Price,
 Gross_Sales, Discounts,
 Sales, COGS, Profit, Date,
 Month_Number, Month_Name,
 Year
] = [
'Segment', 'Country', 'Product',
 'Discount Band', 'Units Sold',
 'Manufacturing Price', 'Sale Price',
 'Gross Sales', 'Discounts',
 'Sales', 'COGS', 'Profit', 'Date',
 'Month Number', 'Month Name', 'Year']

# %% [markdown]
# ## Remove all special characters

# %%
Numerical_Columns = [Units_Sold, Manufacturing_Price, Sale_Price, Gross_Sales, Discounts, Sales, COGS, Profit]
 
df[Numerical_Columns] = df[Numerical_Columns].replace({'\$':'','-':'0',',':''},regex=True)
df.head()
# Out:
#       Segment  Country    Product Discount Band Units Sold  \
# 0  Government   Canada  Carretera          None    1618.50
# 1  Government  Germany  Carretera          None    1321.00
# 2   Midmarket   France  Carretera          None    2178.00
# 3   Midmarket  Germany  Carretera          None     888.00
# 4   Midmarket   Mexico  Carretera          None    2470.00
#
#   Manufacturing Price Sale Price Gross Sales Discounts     Sales      COGS  \
# 0                3.00      20.00    32370.00         0  32370.00  16185.00
# 1                3.00      20.00    26420.00         0  26420.00  13210.00
# 2                3.00      15.00    32670.00         0  32670.00  21780.00
# 3                3.00      15.00    13320.00         0  13320.00   8880.00
# 4                3.00      15.00    37050.00         0  37050.00  24700.00
#
#      Profit        Date  Month Number Month Name  Year
# 0  16185.00  01/01/2014             1    January  2014
# 1  13210.00  01/01/2014             1    January  2014
# 2  10890.00  01/06/2014             6       June  2014
# 3   4440.00  01/06/2014             6       June  2014
# 4  12350.00  01/06/2014             6       June  2014

# %% [markdown]
# ## Numbers in () are Negative, So to Preppend '-'  to the values

# %%
df[Numerical_Columns] = df[Numerical_Columns].replace({'\(':'-','\)':'',' ':''},regex=True)
df.head()
# Out:
#       Segment  Country    Product Discount Band Units Sold  \
# 0  Government   Canada  Carretera          None    1618.50
# 1  Government  Germany  Carretera          None    1321.00
# 2   Midmarket   France  Carretera          None    2178.00
# 3   Midmarket  Germany  Carretera          None     888.00
# 4   Midmarket   Mexico  Carretera          None    2470.00
#
#   Manufacturing Price Sale Price Gross Sales Discounts     Sales      COGS  \
# 0                3.00      20.00    32370.00         0  32370.00  16185.00
# 1                3.00      20.00    26420.00         0  26420.00  13210.00
# 2                3.00      15.00    32670.00         0  32670.00  21780.00
# 3                3.00      15.00    13320.00         0  13320.00   8880.00
# 4                3.00      15.00    37050.00         0  37050.00  24700.00
#
#      Profit        Date  Month Number Month Name  Year
# 0  16185.00  01/01/2014             1    January  2014
# 1  13210.00  01/01/2014             1    January  2014
# 2  10890.00  01/06/2014             6       June  2014
# 3   4440.00  01/06/2014             6       June  2014
# 4  12350.00  01/06/2014             6       June  2014

# %% [markdown]
# ### convert numerical columns to integer data type

# %%
df[Numerical_Columns] = df[Numerical_Columns].astype(float)
df[Units_Sold] = df[Units_Sold].astype(int)
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None        1618
# 1  Government  Germany  Carretera          None        1321
# 2   Midmarket   France  Carretera          None        2178
# 3   Midmarket  Germany  Carretera          None         888
# 4   Midmarket   Mexico  Carretera          None        2470
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                  3.0        20.0      32370.0        0.0  32370.0  16185.0
# 1                  3.0        20.0      26420.0        0.0  26420.0  13210.0
# 2                  3.0        15.0      32670.0        0.0  32670.0  21780.0
# 3                  3.0        15.0      13320.0        0.0  13320.0   8880.0
# 4                  3.0        15.0      37050.0        0.0  37050.0  24700.0
#
#     Profit        Date  Month Number Month Name  Year
# 0  16185.0  01/01/2014             1    January  2014
# 1  13210.0  01/01/2014             1    January  2014
# 2  10890.0  01/06/2014             6       June  2014
# 3   4440.0  01/06/2014             6       June  2014
# 4  12350.0  01/06/2014             6       June  2014

# %% [markdown]
# ## Convert date to datetime format

# %%
df[Date]= pd.to_datetime(df[Date])
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None        1618
# 1  Government  Germany  Carretera          None        1321
# 2   Midmarket   France  Carretera          None        2178
# 3   Midmarket  Germany  Carretera          None         888
# 4   Midmarket   Mexico  Carretera          None        2470
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                  3.0        20.0      32370.0        0.0  32370.0  16185.0
# 1                  3.0        20.0      26420.0        0.0  26420.0  13210.0
# 2                  3.0        15.0      32670.0        0.0  32670.0  21780.0
# 3                  3.0        15.0      13320.0        0.0  13320.0   8880.0
# 4                  3.0        15.0      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# 1  13210.0 2014-01-01             1    January  2014
# 2  10890.0 2014-01-06             6       June  2014
# 3   4440.0 2014-01-06             6       June  2014
# 4  12350.0 2014-01-06             6       June  2014

# %% [markdown]
# ## Delete Non essential columns

# %%
Non_Essential_columns = [Month_Number, Month_Name, Year]

df = df.drop(Non_Essential_columns, axis=1)
 
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None        1618
# 1  Government  Germany  Carretera          None        1321
# 2   Midmarket   France  Carretera          None        2178
# 3   Midmarket  Germany  Carretera          None         888
# 4   Midmarket   Mexico  Carretera          None        2470
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                  3.0        20.0      32370.0        0.0  32370.0  16185.0
# 1                  3.0        20.0      26420.0        0.0  26420.0  13210.0
# 2                  3.0        15.0      32670.0        0.0  32670.0  21780.0
# 3                  3.0        15.0      13320.0        0.0  13320.0   8880.0
# 4                  3.0        15.0      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date
# 0  16185.0 2014-01-01
# 1  13210.0 2014-01-01
# 2  10890.0 2014-01-06
# 3   4440.0 2014-01-06
# 4  12350.0 2014-01-06

# %%
# make dataframe interactive
idf = df.interactive()

# %%
Numerical_List=[Sales, Units_Sold, Profit]

# %%
# Create a new DataFrame with only the columns you want
linked_df,idf = df[[Segment] + Numerical_List], df[[Segment] + Numerical_List].interactive()

# Display the interactive DataFrame
linked_df.head()
# Out:
#       Segment    Sales  Units Sold   Profit
# 0  Government  32370.0        1618  16185.0
# 1  Government  26420.0        1321  13210.0
# 2   Midmarket  32670.0        2178  10890.0
# 3   Midmarket  13320.0         888   4440.0
# 4   Midmarket  37050.0        2470  12350.0

# %%
#Radio buttons for Numeric Measures
yaxis_col = pn.widgets.RadioButtonGroup(name='Y axis',
                                       options= Numerical_List,
                                       button_type='success')
yaxis_col
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['Sales', 'Units Sold', ...], value='Sales')

# %%
# Create a new DataFrame with only the columns you want
idf = df[[Segment] + Numerical_List].interactive()

# Display the interactive DataFrame
idf.head()
# Out:
# <div id='753e307d-15eb-4412-97dd-efe0210f61ae'>
#   <div id="b2b6d5cd-8d89-4709-ab0c-5248c9f84e1c" data-root-id="753e307d-15eb-4412-97dd-efe0210f61ae" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6c89a912-1846-42ff-9b82-99809f27206a":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"753e307d-15eb-4412-97dd-efe0210f61ae","attributes":{"name":"Row00935","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"5448ac47-238e-416b-a136-fbef56918946","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"796bf742-aeeb-410c-addd-50008e1ce84d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7b2cd74d-0822-4b7e-bd4b-7cd60d356302","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"cd3fe495-cb32-4f6a-91ea-42a128d1f4f4","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"a02e1334-5283-4c3d-aca5-3bf484a8d080","attributes":{"name":"Column00920","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"5448ac47-238e-416b-a136-fbef56918946"},{"id":"796bf742-aeeb-410c-addd-50008e1ce84d"},{"id":"7b2cd74d-0822-4b7e-bd4b-7cd60d356302"},{"id":"cd3fe495-cb32-4f6a-91ea-42a128d1f4f4"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"b05700e7-fbc8-463c-8f97-dbc962f5114f","attributes":{"name":"Column00932","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"5448ac47-238e-416b-a136-fbef56918946"},{"id":"796bf742-aeeb-410c-addd-50008e1ce84d"},{"id":"7b2cd74d-0822-4b7e-bd4b-7cd60d356302"},{"id":"cd3fe495-cb32-4f6a-91ea-42a128d1f4f4"}],"margin":0,"align":"start"}},{"type":"object","name":"Row","id":"daa6c654-975d-47ec-ba50-8c90daccc5fa","attributes":{"name":"Row00929","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"5448ac47-238e-416b-a136-fbef56918946"},{"id":"796bf742-aeeb-410c-addd-50008e1ce84d"},{"id":"7b2cd74d-0822-4b7e-bd4b-7cd60d356302"},{"id":"cd3fe495-cb32-4f6a-91ea-42a128d1f4f4"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"80b0612d-7a6c-4585-b893-2e1ea284b806","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"5448ac47-238e-416b-a136-fbef56918946"},{"type":"object","name":"ImportedStyleSheet","id":"d8a1421f-ef40-4358-9332-8976cad258f0","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/dataframe.css"}},{"id":"7b2cd74d-0822-4b7e-bd4b-7cd60d356302"},{"id":"cd3fe495-cb32-4f6a-91ea-42a128d1f4f4"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Segment&lt;/th&gt;\n      &lt;th&gt;Sales&lt;/th&gt;\n      &lt;th&gt;Units Sold&lt;/th&gt;\n      &lt;th&gt;Profit&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Government&lt;/td&gt;\n      &lt;td&gt;32370.0&lt;/td&gt;\n      &lt;td&gt;1618&lt;/td&gt;\n      &lt;td&gt;16185.0&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Govern ...

# %% [markdown]
# ## Pipeline

# %%
pipeline = (idf.pipe(lambda idf: idf
                     .groupby(Segment)[yaxis_col.value]
                     .sum())
            .to_frame()
            .reset_index()
            .reset_index(drop=True)
           )

pipeline
# Out:
# <div id='56de5724-64d8-4ef6-a87a-36583b94e8b4'>
#   <div id="b22bee83-087e-4db1-a519-0a7d2d9ac8aa" data-root-id="56de5724-64d8-4ef6-a87a-36583b94e8b4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"fd964f72-3302-4a1d-974f-df021a793087":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"56de5724-64d8-4ef6-a87a-36583b94e8b4","attributes":{"name":"Row01074","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"8ddc280b-5326-4a83-8a92-f329362db879","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8a243718-f20a-4fb6-b5dd-4f681da1bde6","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"460763e8-4fcd-4cbd-9daf-968c76daca20","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"fa128209-7cfe-4b36-a4aa-6bc299a08428","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"8621c6ea-e19b-41f9-94e1-af3084e4bca0","attributes":{"name":"Column01059","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8ddc280b-5326-4a83-8a92-f329362db879"},{"id":"8a243718-f20a-4fb6-b5dd-4f681da1bde6"},{"id":"460763e8-4fcd-4cbd-9daf-968c76daca20"},{"id":"fa128209-7cfe-4b36-a4aa-6bc299a08428"}],"margin":0,"align":"start","children":[{"type":"object","name":"Column","id":"1a37c48c-3329-4e17-8ffa-1905440ad777","attributes":{"name":"Column01071","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8ddc280b-5326-4a83-8a92-f329362db879"},{"id":"8a243718-f20a-4fb6-b5dd-4f681da1bde6"},{"id":"460763e8-4fcd-4cbd-9daf-968c76daca20"},{"id":"fa128209-7cfe-4b36-a4aa-6bc299a08428"}],"margin":0,"align":"start"}},{"type":"object","name":"Row","id":"f03a643b-f1c2-43f5-990c-2c8552c68506","attributes":{"name":"Row01068","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8ddc280b-5326-4a83-8a92-f329362db879"},{"id":"8a243718-f20a-4fb6-b5dd-4f681da1bde6"},{"id":"460763e8-4fcd-4cbd-9daf-968c76daca20"},{"id":"fa128209-7cfe-4b36-a4aa-6bc299a08428"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"2e99d5df-964b-4274-8c65-68a2d4b6b1ff","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"8ddc280b-5326-4a83-8a92-f329362db879"},{"type":"object","name":"ImportedStyleSheet","id":"338a6b81-3960-4d1b-8a70-15c6fef2aa8b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.1/dist/css/dataframe.css"}},{"id":"460763e8-4fcd-4cbd-9daf-968c76daca20"},{"id":"fa128209-7cfe-4b36-a4aa-6bc299a08428"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Segment&lt;/th&gt;\n      &lt;th&gt;Sales&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;Channel Partners&lt;/td&gt;\n      &lt;td&gt;1800593.64&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;Enterprise&lt;/td&gt;\n      &lt;td&gt;19611694.38&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&g ...

# %%
summary = pn.pane.Markdown('')

yaxis_col = pn.widgets.RadioButtonGroup(name='Y axis',
                                       options= Numerical_List,
                                       button_type='success')

def change_text(event):
    
    linked_df_pipeline = (linked_df.pipe(lambda linked_df: linked_df
                     .groupby(Segment)[yaxis_col.value]
                     .sum())
                      .to_frame()
                      .reset_index()
                      .reset_index(drop=True))
    maxValueIdx=  linked_df_pipeline[yaxis_col.value].idxmax()
    maxValue=   linked_df_pipeline[yaxis_col.value].max()
    minValueIdx=  linked_df_pipeline[yaxis_col.value].idxmin()
    minValue=   linked_df_pipeline[yaxis_col.value].min()
    MaxSegmentName =  linked_df_pipeline.loc[maxValueIdx][Segment]
    MinSegmentName =  linked_df_pipeline.loc[minValueIdx][Segment]
    summary.object = f'The {MaxSegmentName} has the highest {yaxis_col.value} of ${maxValue}. The {MinSegmentName} has the lowest {yaxis_col.value} of ${minValue}.',

    

yaxis_col.param.watch(change_text, 'value')

pn.Row(yaxis_col, summary)
# Out:
# Row
#     [0] RadioButtonGroup(button_type='success', name='Y axis', options=['Sales', 'Units Sold', ...], value='Sales')
#     [1] Markdown(str)

# %%
colourlist = LinearSegmentedColormap.from_list('Blue',['blue', 'white'])
colourlist.set_under(color='red')

 

SegmentPlot= pipeline.hvplot(kind='bar', x= Segment,
                             y= yaxis_col,
                             color= yaxis_col,
                             cmap=colourlist,
                             legend=False).opts(show_grid=True)


SegmentPlot 
summary
# Out:
# Markdown(str)

# %%
summary = pn.pane.Markdown('')
 
yaxis_col = pn.widgets.RadioButtonGroup(name='Y axis',
                                       options= Numerical_List,
                                       button_type='success')

def change_text(event):
    
    linked_df_pipeline = (linked_df.pipe(lambda linked_df: linked_df
                     .groupby(Segment)[yaxis_col.value]
                     .sum())
                      .to_frame()
                      .reset_index()
                      .reset_index(drop=True))
    maxValueIdx=  linked_df_pipeline[yaxis_col.value].idxmax()
    maxValue=   linked_df_pipeline[yaxis_col.value].max()
    minValueIdx=  linked_df_pipeline[yaxis_col.value].idxmin()
    minValue=   linked_df_pipeline[yaxis_col.value].min()
    MaxSegmentName =  linked_df_pipeline.loc[maxValueIdx][Segment]
    MinSegmentName =  linked_df_pipeline.loc[minValueIdx][Segment]
    summary.object = f'## The {MaxSegmentName} has the highest {yaxis_col.value} of ${maxValue}. \n ## The {MinSegmentName} has the lowest {yaxis_col.value} of ${minValue}.'
    

yaxis_col.param.watch(change_text, 'value')

 

colourlist = LinearSegmentedColormap.from_list('Blue',['blue', 'white'])
colourlist.set_under(color='red')

 

SegmentPlot= pipeline.hvplot(kind='bar', x= Segment,
                             y= yaxis_col,
                             color= yaxis_col,
                             cmap=colourlist,
                             legend=False).opts(show_grid=True)

# %%
template = pn.template.FastListTemplate(main= [pn.Row(summary, styles={'background': 'LightGray'}),
                                              pn.Row(SegmentPlot)],
                                        accent_base_color='Blue',
                                        header_background='Red',
                                       )
template.servable()
# Out:
# FastListTemplate
#     [js_area] HTML(None, height=0, margin=0, sizing_mode='fixed', width=0)
#     [actions] TemplateActions()
#     [browser_info] BrowserInfo(dark_mode=False, device_pixel_ratio=1.125, language='en-US', timezone='Africa/Lagos', timezone_offset=-60, webdriver=False)
#     [busy_indicator] LoadingSpinner(height=20, width=20)
#     [2452087012992] Row(styles={'background': '...})
#         [0] Markdown(str)
#     [2452087012704] Row
#         [0] Interactive(Interactive)

# %%
full_discount_band_List= df[Discount_Band].unique().tolist()


full_country_List=  df[Country].unique().tolist()
full_country_List =sorted(full_country_List)



full_product_List=  df[Product].unique().tolist()
full_product_List = sorted(full_product_List)

type(full_discount_band_List)
